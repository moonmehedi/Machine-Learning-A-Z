# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv(r"D:\ml\resorces\Machine Learning-A-Z-Codes-Datasets\Machine Learning A-Z (Codes and Datasets)\132 - Machine-Learning-A-Z-Model-Selection\Machine Learning A-Z (Model Selection)\Regression\Data.csv")
data
# Out:
#          AT      V       AP     RH      PE
# 0     14.96  41.76  1024.07  73.17  463.26
# 1     25.18  62.96  1020.04  59.08  444.37
# 2      5.11  39.40  1012.16  92.14  488.56
# 3     20.86  57.32  1010.24  76.64  446.48
# 4     10.82  37.50  1009.23  96.62  473.90
# ...     ...    ...      ...    ...     ...
# 9563  16.65  49.69  1014.01  91.00  460.03
# 9564  13.19  39.18  1023.67  66.78  469.62
# 9565  31.32  74.33  1012.92  36.48  429.57
# 9566  24.48  69.45  1013.86  62.39  435.74
# 9567  21.60  62.52  1017.23  67.87  453.28
#
# [9568 rows x 5 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9568 entries, 0 to 9567
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   AT      9568 non-null   float64
#  1   V       9568 non-null   float64
#  2   AP      9568 non-null   float64
#  3   RH      9568 non-null   float64
#  4   PE      9568 non-null   float64
# dtypes: float64(5)
# memory usage: 373.9 KB

# %%
# for at
data.describe()
# Out:
#                 AT            V           AP           RH           PE
# count  9568.000000  9568.000000  9568.000000  9568.000000  9568.000000
# mean     19.651231    54.305804  1013.259078    73.308978   454.365009
# std       7.452473    12.707893     5.938784    14.600269    17.066995
# min       1.810000    25.360000   992.890000    25.560000   420.260000
# 25%      13.510000    41.740000  1009.100000    63.327500   439.750000
# 50%      20.345000    52.080000  1012.940000    74.975000   451.550000
# 75%      25.720000    66.540000  1017.260000    84.830000   468.430000
# max      37.110000    81.560000  1033.300000   100.160000   495.760000

# %%
# relation with the predicted values

data.set_index("AT").plot(subplots=True,
                          figsize=(10, 24))
# Out:
# array([<Axes: xlabel='AT'>, <Axes: xlabel='AT'>, <Axes: xlabel='AT'>,
#        <Axes: xlabel='AT'>], dtype=object)

# %%
# can not justify the data should feature scale the data

from sklearn.preprocessing import StandardScaler

Scaller_x = StandardScaler()
data_scaled = Scaller_x.fit_transform(data)

# %%
new_data = pd.DataFrame(data_scaled, columns=data.columns)
new_data
# Out:
# 0       0.521208
# 1      -0.585664
# 2       2.003679
# 3      -0.462028
# 4       1.144666
#           ...
# 9563    0.331944
# 9564    0.893877
# 9565   -1.452881
# 9566   -1.091345
# 9567   -0.063577
# Name: PE, Length: 9568, dtype: float64

# %%
rows = data.columns[:-1]

fig, axis = plt.subplots(nrows=len(rows), ncols=1, figsize=(12, 24))

for i, column in enumerate(rows):
    axis[i].scatter(data[column], data["PE"])
    axis[i].set_title(f"{column} vs PE")
    axis[i].set_xlabel(column)
    axis[i].set_ylabel('PE')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
