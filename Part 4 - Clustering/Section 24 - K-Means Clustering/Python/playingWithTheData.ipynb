# %%
import numpy as np

import pandas as pd

import matplotlib.pyplot as plt

# %%
data = pd.read_csv(r'Mall_Customers.csv')
data
# Out:
#      CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]

# %%
data.describe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 data.describe()
# ----> 2 data.iloc[:, i+1].head(5)
#
# NameError: name 'i' is not defined

# %%
ColumnOfFigure=data.columns[1:-1]


fig,axis=plt.subplots(nrows=len(ColumnOfFigure),ncols=1,figsize=(24,24))


for i,column in enumerate(ColumnOfFigure):
    axis[i].scatter(data.iloc[:,i+1],data['Spending Score (1-100)'])
    axis[i].set_xlabel(column)
    axis[i].set_ylabel('spending')

# %%
plt.scatter(data['Age'], data['Annual Income (k$)'])
